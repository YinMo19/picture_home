# %%
# from mpl_toolkits import mplot3d
# import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.animation import FuncAnimation
from scipy.integrate import odeint

config = {
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{CJK}",  # 预先导入CJK宏包处理中文
}
plt.rcParams.update(config)

# %%
time = np.array([0.22, 1.18, 1.43, 1.45])

ipc_id = np.array(
    [r"${\rm 5eqn}$", r"${\rm zjl37}$", r"${\rm YinMo19}$", r"${\rm Crystalizer}$"]
)
rank = 10 / time

# %%
plt.figure()
ax = plt.gca()

bars = ax.bar(ipc_id, rank)
plt.ylabel(r"${\rm RANK}$", color="teal")
plt.xlabel(r"${\rm IPC~~PLAYER}$", color="teal")
plt.savefig("rank.png", dpi=400)
